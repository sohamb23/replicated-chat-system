# %%
part1_times = [0.026021242141723633, 0.010699033737182617, 0.009298086166381836, 0.00840902328491211, 0.007399320602416992, 0.007459878921508789, 0.007211923599243164, 0.008981943130493164, 0.009327888488769531, 0.010308265686035156]

part2_times = [1.1283328533172607, 0.02769303321838379, 0.022424697875976562, 0.021759986877441406, 0.02444911003112793, 0.024938106536865234, 0.023545026779174805, 0.023561954498291016, 0.02277207374572754, 0.02266216278076172]

# %%
import matplotlib.pyplot as plt
times = range(10)
plt.plot(times, part1_times, label = "part 1 run-times")
plt.plot(times, part2_times, label = "part 2 run-times")
plt.title("Comparison of Part 1 and Part 2 Runtimes")
plt.xlabel("trial")
plt.ylabel("time (s)")
plt.legend()
plt.savefig("runtime.png")
